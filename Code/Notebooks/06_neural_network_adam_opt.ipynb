# %%
import tensorflow as tf 
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import SparseCategoricalCrossentropy


model = Sequential(
    [Dense(units = 25 , activation ='relu'),    # first hidden layer 
     Dense(units = 15 , activation = 'relu'),   # second hidden layer 
     Dense(units = 10 , activation = 'linear') # output layer with LINEAR as activation function
     ]
)
# this is more accurate numerically and gives precision
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate = 1e - 3) ,
    loss = SparseCategoricalCrossentropy(from_logits = True))

model.fit(X,Y,epochs = 100)

# Now the NN outputs the logits z values not probabilities anymore
# so we catch that and apply softmax ourselves

logits = model(X)
f_x = tf.nn.softmax(logits) # Same goes for logistic Regression too just use sigmoid there
