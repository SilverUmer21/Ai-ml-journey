# %%
## model.fit(X,Y,epochs = 100)
## model.fit() tells tensorflow to to fit the model we described in step 1 
## using the loss of the cost function that we specified in step 2 
## to the dataset X and Y 

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import BinaryCrossentropy

# step 1    Creating the model
# this defines the entire architecture of neural networks  
model = Sequential([ 
    Dense(units = 25 , activation = 'sigmoid') ,
    Dense( units = 15 , activation = 'sigmoid') ,
    Dense(units = 1 , activation = 'sigmoid') ,
    ])

# step 2    Loss and Cost function
# we are using the same loss and cost function here as logistic regression 
# as we are doing binary classification (digit recognition as 1 or 0 )so we compare Result and Ground truth 
# or prediction vs target -> this is also called Binary Cross Entropy in tensorflow


 
model.compile(loss = BinaryCrossentropy())

# step 3 
#model.fit(X,Y,epochs = 100 )
